# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from pathlib import Path
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv('FoodAccessResearchAtlasData2019.csv',encoding= 'unicode_escape')
df.head()
# Out:
#    ï»¿CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0      1001020100  Alabama  Autauga County      1     1912      693
# 1      1001020200  Alabama  Autauga County      1     2170      743
# 2      1001020300  Alabama  Autauga County      1     3373     1256
# 3      1001020400  Alabama  Autauga County      1     4386     1722
# 4      1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0      0.00                  0  ...
# 1                  0     181.0      8.34                  1  ...
# 2                  0       0.0      0.00                  0  ...
# 3                  0       0.0      0.00                  0  ...
# 4                  0     181.0      1.68                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# 1         214.0       888.0      1217.0         5.0         0.0        5.0
# 2         439.0      2576.0       647.0        17.0         5.0       11.0
# 3         904.0      4086.0       193.0        18.0         4.0       11.0
# 4        1126.0      8666.0      1437.0       296.0         9.0       48.0
#
#    TractOMultir  TractHispanic  TractHUNV  TractSNAP
# 0          45.0           44.0        6.0      102.0
# 1          55.0           75.0       89.0      156.0
# 2         117.0           87.0       99.0      172.0
# 3          74.0           85.0       21.0       98.0
# 4         310.0          355.0      230.0      339.0
#
# [5 rows x 147 columns]

# %%
#Average pop by state
avepopstate = df.groupby(['State'])['Pop2010'].mean().round(2)
avepopstate
# Out:
# State
# Alabama                 4057.50
# Alaska                  4252.88
# Arizona                 4205.27
# Arkansas                4250.61
# California              4642.82
# Colorado                4049.27
# Connecticut             4316.54
# Delaware                4195.95
# District of Columbia    3361.58
# Florida                 4495.77
# Georgia                 4950.26
# Hawaii                  4237.70
# Idaho                   5260.34
# Illinois                4118.98
# Indiana                 4302.46
# Iowa                    3701.52
# Kansas                  3724.70
# Kentucky                3909.34
# Louisiana               4015.39
# Maine                   3784.50
# Maryland                4153.63
# Massachusetts           4463.28
# Michigan                3586.23
# Minnesota               3975.96
# Mississippi             4502.73
# Missouri                4305.48
# Montana                 3650.98
# Nebraska                3432.97
# Nevada                  3971.40
# New Hampshire           4508.46
# New Jersey              4391.56
# New Mexico              4134.90
# New York                3979.08
# North Carolina          4384.13
# North Dakota            3280.93
# Ohio                    3919.98
# Oklahoma                3586.38
# Oregon                  4638.10
# Pennsylvania            3957.13
# Rhode Island            4367.50
# South Carolina          4239.56
# South Dakota            3667.48
# Tennessee               4261.99
# Texas                   4800.60
# Utah                    4724.59
# Vermont                 3419.35
# Virginia                4242.32
# Washington              4653.66
# West Virginia           3828.50
# Wisconsin               4085.48
# Wyoming                 4302.49
# Name: Pop2010, dtype: float64
